# %%
# Setup Imports
import numpy as np
import matplotlib.pyplot as plt

# Loading Results from OL4.py app outputs
results = [{
        "title":"Translation",
        "data": np.loadtxt("translation-results.txt"),
    },{
        "title":"Parity",
        "data": np.loadtxt("translation-results.txt"),
    }]

# %%
results[0]["data"]
# Out:
# array([[0.33333334, 0.36216217],
#        [0.19101124, 0.24858756],
#        [0.26845637, 0.27380952],
#        [0.24712643, 0.23243241],
#        [0.16666667, 0.28481013],
#        [0.29761904, 0.30635837],
#        [0.14201184, 0.20370369],
#        [0.22033899, 0.26288658],
#        [0.17877094, 0.35195529],
#        [0.17582418, 0.29090908]])

# %%
# Create a 1x2 grid for the Plots (subplots)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Default Values for all Plots
for i, axis in enumerate(axes.ravel()):

    # Setup Data Layers for Plots
    axis.set_title(results[i]["title"])

    axis.boxplot(results[i]["data"], notch=True)
    axis.set_ylabel('Accuracy (P)')
    axis.set_xticks([1, 2], ['Simple', 'LSTM'])


# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()
