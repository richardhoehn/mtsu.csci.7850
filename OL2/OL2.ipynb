# %%
# Setup Imports
import numpy as np
import matplotlib.pyplot as plt

# Loading Results from OL2.py Plotting Outputs
results = [{
        "title":"CIFAR-10",
        "single": np.loadtxt("cifar10-single.txt"),
        "wide": np.loadtxt("cifar10-wide.txt"),
        "deep": np.loadtxt("cifar10-deep.txt"),
        "resid": np.loadtxt("cifar10-resid.txt"),
    },{
        "title":"CIFAR-100",
        "single": np.loadtxt("cifar100-single.txt"),
        "wide": np.loadtxt("cifar100-wide.txt"),
        "deep": np.loadtxt("cifar100-deep.txt"),
        "resid": np.loadtxt("cifar100-resid.txt"),
    }]

# %%
# Create a 2x2 grid for the Plots (subplots)
fig, axes = plt.subplots(2, 1, figsize=(15, 15))

# Default Values for all Plots
for i, axis in enumerate(axes.ravel()):

    # Setup Data Layers for Plots
    axis.set_title(results[i]["title"])

    # Setup Single
    data = results[i]["single"]
    axis.plot(np.arange(0, data.shape[1]), np.mean(data, 0),label='Single')
    axis.fill_between(np.arange(0, data.shape[1]), np.mean(data, 0)-(1.96*np.std(data, 0)/np.sqrt(data.shape[0])), np.mean(data, 0)+(1.96*np.std(data, 0)/np.sqrt(data.shape[0])), alpha=0.5)

    # Setup Single
    data = results[i]["wide"]
    axis.plot(np.arange(0, data.shape[1]), np.mean(data, 0),label='Wide')
    axis.fill_between(np.arange(0, data.shape[1]), np.mean(data, 0)-(1.96*np.std(data, 0)/np.sqrt(data.shape[0])), np.mean(data, 0)+(1.96*np.std(data, 0)/np.sqrt(data.shape[0])), alpha=0.5)

    # Setup Single
    data = results[i]["deep"]
    axis.plot(np.arange(0, data.shape[1]), np.mean(data, 0),label='Deep')
    axis.fill_between(np.arange(0, data.shape[1]), np.mean(data, 0)-(1.96*np.std(data, 0)/np.sqrt(data.shape[0])), np.mean(data, 0)+(1.96*np.std(data, 0)/np.sqrt(data.shape[0])), alpha=0.5)

    # Setup Single
    data = results[i]["resid"]
    axis.plot(np.arange(0, data.shape[1]), np.mean(data, 0),label='Residual')
    axis.fill_between(np.arange(0, data.shape[1]), np.mean(data, 0)-(1.96*np.std(data, 0)/np.sqrt(data.shape[0])), np.mean(data, 0)+(1.96*np.std(data, 0)/np.sqrt(data.shape[0])), alpha=0.5)

    # General Setting and UI configs that are the same on each Plot
    axis.set_ylabel('Validation Accuracy (P)')
    #axis.set_ylim(results[i]["limits"])
    axis.set_xlabel('Epoch')
    #axis.set_xticks(ticks=np.arange(0, 11), labels=np.arange(0, 110, 10))
    axis.legend(loc='lower right') 

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # Ansers to Questions
#
# ## Question 1
# In my case the "Wide" performed the best of all of them. On the Cifar-100 The Redisual came close but the Wide-notwork still did better.
#
# ## Question 2
# I think in my case teh wide performed better becasue I used a higher number of hidden dimensions. With this inmind I am guessing that the Cifar-10 was able to posisble better learn with a bigger spread than needing more back propogation.
#
# ## Question 3
# Overall, I think I was just scratciht hte surface with testing different decay factors. In addition I could have tried more combinations of the hidden dimension vs. hidden layers to see if staying withing the constraints of the paramaters (150K and 300K) would yeild better results.
#
# ## Question 4
# I woudld expects that as I change the "Deep" network to because more "shallow" and more like the wide that the results would converge more, maybe evenin yeild better results. In addition by changing the decay factor I might be able to help a bit more with the overfitting on the single network.
#
# ## Question 5
# Overall, I think I used my notebook (physical) to list changes and write down the accuracy updates to see if I can construct a matrix of what works best. Below is an example of how I already used it - sorry for the bad handwriting.
# ![Notes](https://raw.githubusercontent.com/richardhoehn/mtsu.csci.7850/main/OL2/IMG_4352.JPG)
#
# ## Question 6
# I feel I have some gaps on how t use batch sizes and if they are important to the results. Maybe we could look into that a bit more again?
#
# ## Question 7
# Getting a bit more familar on how in parctical to tune the hyperparameters better. I know there is a webbased applicaiton that might help capture similar to GIT the progress but cannot rember the name anymore.
